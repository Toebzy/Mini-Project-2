# %%
# import pandas for structuring the data
import pandas as pd

# import numpy for numerical analysis
import numpy as np

# import libs for diagrams inline with the text
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# other utilities
from sklearn import datasets, preprocessing, metrics

# %%
wqw = pd.read_excel('./winequality-white.xlsx', skiprows=1, index_col=None, na_values=['NA'])

# %%
wqw.shape
# Out:
# (4898, 12)

# %%
wqw.sample(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3823            6.7              0.26         0.49             8.1      0.052
# 3271            6.5              0.32         0.34             5.7      0.044
# 2479            6.6              0.24         0.30            13.0      0.052
# 905             8.4              0.19         0.42             1.6      0.047
# 104             7.4              0.25         0.37            13.5      0.060
# 1625            6.4              0.26         0.49             6.4      0.037
# 1901            7.4              0.21         0.30             7.9      0.039
# 681             6.8              0.34         0.69             1.3      0.058
# 305             7.3              0.41         0.24             6.8      0.057
# 832             7.3              0.30         0.34             2.7      0.044
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 3823                 48.0                 197.0  0.99558  3.19       0.48
# 3271                 27.0                  91.0  0.99184  3.28       0.60
# 2479                 18.0                 143.0  0.99825  3.37       0.49
# 905                   9.0                 101.0  0.99400  3.06       0.65
# 104                  52.0                 192.0  0.99750  3.00       0.44
# 1625                 37.0                 161.0  0.99540  3.38       0.53
# 1901                 14.0                 118.0  0.99420  2.96       0.34
# 681                  12.0                 171.0  0.99310  3.06       0.47
# 305                  41.0                 163.0  0.99490  3.20       0.41
# 832                  34.0                 108.0  0.99105  3.36       0.53
#
#       alcohol  quality
# 3823      9.5        5
# 3271     12.0        7
# 2479      9.4        6
# 905      11.1        4
# 104       9.1        5
# 1625      9.7        6
# 1901     10.4        5
# 681       9.7        5
# 305       9.9        6
# 832      12.8        8

# %%
wqr = pd.read_excel('./winequality-red.xlsx', skiprows=1, index_col=None, na_values=['NA'])

# %% [raw]
# wqr.shape

# %%
wqr.sample(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 175             6.9             0.500         0.04             1.5      0.085
# 763             9.3             0.655         0.26             2.0      0.096
# 496             7.8             0.520         0.25             1.9      0.081
# 398            11.5             0.590         0.59             2.6      0.087
# 1065            7.7             0.610         0.18             2.4      0.083
# 487            10.2             0.645         0.36             1.8      0.053
# 1336            6.0             0.500         0.00             1.4      0.057
# 66              7.5             0.520         0.11             1.5      0.079
# 790             7.4             0.370         0.43             2.6      0.082
# 1033            7.5             0.570         0.08             2.6      0.089
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 175                  19.0                  49.0  0.99580  3.35       0.78
# 763                   5.0                  35.0  0.99738  3.25       0.42
# 496                  14.0                  38.0  0.99840  3.43       0.65
# 398                  13.0                  49.0  0.99880  3.18       0.65
# 1065                  6.0                  20.0  0.99630  3.29       0.60
# 487                   5.0                  14.0  0.99820  3.17       0.42
# 1336                 15.0                  26.0  0.99448  3.36       0.45
# 66                   11.0                  39.0  0.99680  3.42       0.58
# 790                  18.0                  82.0  0.99708  3.33       0.68
# 1033                 14.0                  27.0  0.99592  3.30       0.59
#
#       alcohol  quality
# 175       9.5        5
# 763       9.6        5
# 496       9.0        6
# 398      11.0        6
# 1065     10.2        6
# 487      10.0        6
# 1336      9.5        5
# 66        9.6        5
# 790       9.7        6
# 1033     10.4        6

# %%
wqw.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
wqr.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
wqr['type']=0
wqw['type']=1

# %%
wine = pd.concat([wqw, wqr], ignore_index=True)

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality  type
# 0      8.8        6     1
# 1      9.5        6     1
# 2     10.1        6     1
# 3      9.9        6     1
# 4      9.9        6     1

# %%
wine.sample(20)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 602             6.4              0.45         0.07             1.1      0.030
# 4540            5.8              0.28         0.30             3.9      0.026
# 5853            8.5              0.21         0.52             1.9      0.090
# 3385            6.4              0.32         0.31             1.9      0.037
# 3458            5.8              0.32         0.20             2.6      0.027
# 3290            7.8              0.25         0.37             1.0      0.043
# 3799            7.0              0.30         0.28             2.2      0.042
# 2136            7.9              0.18         0.36             5.9      0.058
# 2260            7.6              0.48         0.28            10.4      0.049
# 2849            7.7              0.43         0.37            10.0      0.169
# 4704            6.3              0.36         0.50             8.3      0.053
# 4464            6.6              0.26         0.56            15.4      0.053
# 847             9.2              0.34         0.27             1.2      0.026
# 5712           12.6              0.41         0.54             2.8      0.103
# 4681            5.6              0.27         0.37             0.9      0.025
# 894             5.8              0.26         0.18             1.2      0.031
# 4242            5.9              0.22         0.29             4.2      0.037
# 6063            8.5              0.44         0.50             1.9      0.369
# 541             7.2              0.46         0.65            10.4      0.050
# 750             7.2              0.29         0.40             7.6      0.024
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 602                  10.0                 131.0  0.99050  2.97       0.28
# 4540                 36.0                 105.0  0.98963  3.26       0.58
# 5853                  9.0                  23.0  0.99648  3.36       0.67
# 3385                 34.0                 126.0  0.99000  3.06       0.45
# 3458                 17.0                 123.0  0.98936  3.36       0.78
# 3290                 10.0                  80.0  0.99128  3.08       0.38
# 3799                 21.0                 177.0  0.99166  3.20       0.57
# 2136                 31.0                 132.0  0.99500  3.25       0.52
# 2260                 57.0                 205.0  0.99748  3.24       0.45
# 2849                 22.0                 210.0  0.99776  3.02       0.64
# 4704                 51.0                 202.0  0.99550  3.20       0.51
# 4464                 32.0                 141.0  0.99810  3.11       0.49
# 847                  17.0                  73.0  0.99210  3.08       0.39
# 5712                 19.0                  41.0  0.99939  3.21       0.76
# 4681                 11.0                  49.0  0.98845  3.29       0.33
# 894                  40.0                 114.0  0.99080  3.42       0.40
# 4242                 69.0                 144.0  0.99214  3.13       0.74
# 6063                 15.0                  38.0  0.99634  3.01       1.10
# 541                  76.0                 192.0  0.99760  3.16       0.42
# 750                  56.0                 177.0  0.99280  3.04       0.32
#
#       alcohol  quality  type
# 602     10.80        5     1
# 4540    12.75        6     1
# 5853    10.40        5     0
# 3385    11.80        6     1
# 3458    13.90        7     1
# 3290    11.40        5     1
# 3799    11.40        5     1
# 2136    10.90        6     1
# 2260     9.30        5     1
# 2849     9.50        5     1
# 4704     9.60        6     1
# 4464     9.30        5     1
# 847     10.80        5     1
# 5712    11.30        6     0
# 4681    13.10        6     1
# 894     11.00        7     1
# 4242    10.80        7     1
# 6063     9.40        5     0
# 541      8.70        5     1
# 750     11.50        6     1

# %%
wine.shape
# Out:
# (6497, 13)

# %%
wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# min       0.009000             1.000000              6.000000     0.987110
# 25%       0.038000            17.000000             77.000000     0.992340
# 50%       0.047000            29.000000            118.000000     0.994890
# 75%       0.065000            41.000000            156.000000     0.996990
# max       0.611000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality         type
# count  6497.000000  6497.000000  6497.000000  6497.000000  6497.000000
# mean      3.218501     0.531268    10.491801     5.818378     0.753886
# std       0.160787     0.148806     1.192712     0.873255     0.430779
# min       2.720000     0.220000     8.000000     3.000000     0.000000
# 25%       3.110000     0.430000     9.500000     5.000000     1.000000
# 50%       3.210000     0.510000    10.300000     6.000000     1.000000
# 75%       3.320000     0.600000    11.300000     6.000000     1.000000
# max       4.010000     2.000000    14.900000     9.000000     1.000000

# %%
winecorr=wine.corr()

# %%
sns.heatmap(winecorr, annot=True)

plt.title('Wine Heatmap')

plt.show()

# %%
wine.reset_index()
# Out:
#       index  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0         0            7.0             0.270         0.36            20.7
# 1         1            6.3             0.300         0.34             1.6
# 2         2            8.1             0.280         0.40             6.9
# 3         3            7.2             0.230         0.32             8.5
# 4         4            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492   6492            6.2             0.600         0.08             2.0
# 6493   6493            5.9             0.550         0.10             2.2
# 6494   6494            6.3             0.510         0.13             2.3
# 6495   6495            5.9             0.645         0.12             2.0
# 6496   6496            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0         0.045                 45.0                 170.0  1.00100  3.00
# 1         0.049                 14.0                 132.0  0.99400  3.30
# 2         0.050                 30.0                  97.0  0.99510  3.26
# 3         0.058                 47.0                 186.0  0.99560  3.19
# 4         0.058                 47.0                 186.0  0.99560  3.19
# ...         ...                  ...                   ...      ...   ...
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6493      0.062                 39.0                  51.0  0.99512  3.52
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality  type
# 0          0.45      8.8        6     1
# 1          0.49      9.5        6     1
# 2          0.44     10.1        6     1
# 3          0.40      9.9        6     1
# 4          0.40      9.9        6     1
# ...         ...      ...      ...   ...
# 6492       0.58     10.5        5     0
# 6493       0.76     11.2        6     0
# 6494       0.75     11.0        6     0
# 6495       0.71     10.2        5     0
# 6496       0.66     11.0        6     0
#
# [6497 rows x 14 columns]

# %%
wine.alcohol.plot.box()
# Out:
# <Axes: >

# %%
fw = wine[wine['alcohol'] > 14]
fw.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3918            6.4              0.35         0.28             1.6      0.037
# 4503            5.8              0.61         0.01             8.4      0.041
# 5550           15.9              0.36         0.65             7.5      0.096
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 3918                 31.0                 113.0  0.98779  3.12       0.40
# 4503                 31.0                 104.0  0.99090  3.26       0.72
# 5550                 22.0                  71.0  0.99760  2.98       0.84
#
#       alcohol  quality  type
# 3918    14.20        7     1
# 4503    14.05        7     1
# 5550    14.90        5     0

# %%
plt.figure(figsize=(10, 6))

sns.histplot(wine[wine['type'] == 0]['alcohol'], kde=True, bins=20, color='maroon', label='Red Wine')
sns.histplot(wine[wine['type'] == 1]['alcohol'], kde=True, bins=20, color='skyblue', label='White Wine')

plt.xlabel('Alcohol Content')
plt.ylabel('Frequency')
plt.title('Histogram of Wine Alcohol Content')
plt.legend()

plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.histplot(wine[wine['type'] == 0]['volatile acidity'], kde=True, bins=20, color='maroon', label='Red Wine')
sns.histplot(wine[wine['type'] == 1]['volatile acidity'], kde=True, bins=20, color='skyblue', label='White Wine')

plt.xlabel('Volatile Acidity Content')
plt.ylabel('Frequency')
plt.title('Histogram of Volatile Acidity Content')
plt.legend()

plt.show()

# %%
avg_quality_by_type = wine.groupby('type')['quality'].mean().reset_index()

plt.figure(figsize=(8, 6))
sns.barplot(data=avg_quality_by_type, x='type', y='quality', palette='husl')
plt.xlabel('Wine Type')
plt.ylabel('Average Quality Score')
plt.title('Average Quality Score by Wine Type')
plt.xticks(ticks=[0, 1], labels=['Red', 'White'])

plt.show()

# %%
avg_alcohol_by_type = wine.groupby('type')['alcohol'].mean().reset_index()

plt.figure(figsize=(8, 6))
sns.barplot(data=avg_alcohol_by_type, x='type', y='alcohol', palette='husl')
plt.xlabel('Wine Type')
plt.ylabel('Average Alcohol Score')
plt.title('Average Alcohol Score by Wine Type')
plt.xticks(ticks=[0, 1], labels=['Red', 'White'])

plt.show()

# %%
avg_residualSugar_by_type = wine.groupby('type')['residual sugar'].mean().reset_index()

plt.figure(figsize=(8, 6))
sns.barplot(data=avg_residualSugar_by_type, x='type', y='residual sugar', palette='husl')
plt.xlabel('Wine Type')
plt.ylabel('Average Residual Sugar Score')
plt.title('Average Residual Sugar by Wine Type')
plt.xticks(ticks=[0, 1], labels=['Red', 'White'])

plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.histplot(wine[wine['type'] == 0]['pH'], kde=True, bins=20, color='maroon', label='Red Wine')
sns.histplot(wine[wine['type'] == 1]['pH'], kde=True, bins=20, color='skyblue', label='White Wine')

plt.xlabel('pH Level')
plt.ylabel('Frequency')
plt.title('Histogram of pH Level')
plt.legend()

plt.show()

# %%
qualityCorr = wine[['quality', 'alcohol']]
qualityCorr.corr()
# Out:
#           quality   alcohol
# quality  1.000000  0.444319
# alcohol  0.444319  1.000000

# %%
qualityCorr = wine[['quality', 'density']]
qualityCorr.corr()
# Out:
#           quality   density
# quality  1.000000 -0.305858
# density -0.305858  1.000000

# %%
wine['residual sugar'].plot.box()
# Out:
# <Axes: >

# %%
residualSugar = wine['residual sugar'].sort_values(ascending = False)
residualSugar.head(5)
# Out:
# 1663    31.60
# 1653    31.60
# 3619    26.05
# 3623    26.05
# 1608    23.50
# Name: residual sugar, dtype: float64

# %%
#wine= wine.drop(2781)
#wine.reset_index()

# %%
pH_values= wine['pH']
num_bins = 5 
bin_edges = np.linspace(0, 14, num_bins + 1)

hist, _ = np.histogram(pH_values, bins = bin_edges)

bin_widths = np.diff(bin_edges)
densities = hist / bin_widths 

max_density_index = np.argmax(densities)
subset_with_highest_density = {
    'bin_range': (bin_edges [max_density_index], bin_edges[max_density_index + 1]),
    'density': densities[max_density_index]
}

print(densities)
# Out:
# [   2.5 2317.5    0.     0.     0. ]
